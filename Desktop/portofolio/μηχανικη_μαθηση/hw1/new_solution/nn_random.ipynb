# %%
import numpy as np

# Number of samples
N = 10**6

# Simulate data for H0
x0 = np.random.normal(0, 1, size=(N, 2))

# Simulate data for H1
x1_part1 = np.random.normal(1, 1, size=(N//2, 1))
x1_part2 = np.random.normal(-1, 1, size=(N//2, 1))
x1 = np.vstack([x1_part1, x1_part2])
x1 = np.hstack([x1, np.random.normal(0, 1, size=(N, 1))])

# Combine the data and create labels
X = np.vstack([x0, x1])
y = np.array([0]*N + [1]*N)

# %%
def bayes_decision_rule(x):
    f0 = np.exp(-0.5 * np.sum(x**2, axis=1))  # Likelihood under H0
    f1 = 0.5 * (np.exp(-0.5 * (x[:, 0] - 1)**2) + np.exp(-0.5 * (x[:, 0] + 1)**2)) * np.exp(-0.5 * x[:, 1]**2)  # Likelihood under H1
    return f1 > f0

# Apply the Bayes decision rule
y_bayes = bayes_decision_rule(X)

# %%
# Estimate error
error_rate_bayes = np.mean(y_bayes != y)
print("Bayes Decision Rule Error Rate:", error_rate_bayes)
# Out:
# Bayes Decision Rule Error Rate: 0.396392

# %%
# Function to generate data
def generate_data(N):
    # H0 data
    x0 = np.random.normal(0, 1, size=(N, 2))
    
    # H1 data
    x1_part1 = np.random.normal(1, 1, size=(N//2, 1))
    x1_part2 = np.random.normal(-1, 1, size=(N//2, 1))
    x1 = np.vstack([x1_part1, x1_part2])
    x1 = np.hstack([x1, np.random.normal(0, 1, size=(N, 1))])
    
    X = np.vstack([x0, x1])
    y = np.array([0]*N + [1]*N)
    
    return X, y

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\vanes\anaconda3
#
#   added / updated specs:
#     - cpuonly
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cpuonly-2.0                |                0           2 KB  pytorch
#     libjpeg-turbo-2.0.0        |       h196d8e1_0         618 KB
#     libuv-1.44.2               |       h2bbff1b_0         288 KB
#     pytorch-2.3.0              |      py3.9_cpu_0       138.3 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
#     torchaudio-2.3.0           |         py39_cpu         5.7 MB  pytorch
#     torchvision-0.18.0         |         py39_cpu         6.5 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       151.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cpuonly            pytorch/noarch::cpuonly-2.0-0 None
#   libjpeg-turbo      pkgs/main/win-64::libjpeg-turbo-2.0.0-h196d8e1_0 None
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0 None
#   pytorch            pytorch/win-64::pytorch-2.3.0-py3.9_cpu_0 None
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu None
#   torchaudio         pytorch/win-64::torchaudio-2.3.0-py39_cpu None
#   torchvision        pytorch/win-64::torchvision-0.18.0-py39_cpu None
#
#
#
# Downloading and Extracting Packages
#
# torchaudio-2.3.0     | 5.7 MB    |            |   0%
# torchaudio-2.3.0     | 5.7 MB    |            |   0%
# torchaudio-2.3.0     | 5.7 MB    | 2          |   2%
# torchaudio-2.3.0     | 5.7 MB    | 4          |   4%
# torchaudio-2.3.0     | 5.7 MB    | 6          |   7%
# torchaudio-2.3.0     | 5.7 MB    | 9          |   9%
# torchaudio-2.3.0     | 5.7 MB    | #1         |  11%
# torchaudio-2.3.0     | 5.7 MB    | #3         |  13%
# torchaudio-2.3.0     | 5.7 MB    | #5         |  16%
# torchaudio-2.3.0     | 5.7 MB    | #7         |  18%
# torchaudio-2.3.0     | 5.7 MB    | #9         |  20%
# torchaudio-2.3.0     | 5.7 MB    | ##2        |  22%
# torchaudio-2.3.0     | 5.7 MB    | ##4        |  25%
# torchaudio-2.3.0     | 5.7 MB    | ##6        |  27%
# torchaudio-2.3.0     | 5.7 MB    | ##8        |  29%
# torchaudio-2.3.0     | 5.7 MB    | ###1       |  31%
# torchaudio-2.3.0     | 5.7 MB    | ###3       |  33%
# torchaudio-2.3.0     | 5.7 MB    | ###5       |  36%
# torchaudio-2.3.0     | 5.7 MB    | ###8       |  38%
# torchaudio-2.3.0     | 5.7 MB    | ####       |  40%
# torchaudio-2.3.0     | 5.7 MB    | ####2      |  42%
# torchaudio-2.3.0     | 5.7 MB    | ####4      |  45%
# torchaudio-2.3.0     | 5.7 MB    | ####6      |  47%
# torchaudio-2.3.0     | 5.7 MB    | ####8      |  49%
# torchaudio-2.3.0     | 5.7 MB    | #####1     |  51%
# torchaudio-2.3.0     | 5.7 MB    | #####3     |  54%
# torchaudio-2.3.0     | 5.7 MB    | #####6     |  56%
# torchaudio-2.3.0     | 5.7 MB    | #####8     |  58%
# torchaudio-2.3.0     | 5.7 MB    | ######     |  60%
# torchaudio-2.3.0     | 5.7 MB    | ######2    |  63%
# torchaudio-2.3.0     | 5.7 MB    | ######5    |  65%
# torchaudio-2.3.0     | 5.7 MB    | ######7    |  67%
# torchaudio-2.3.0     | 5.7 MB    | ######9    |  69%
# torchaudio-2.3.0     | 5.7 MB    | #######1   |  72%
# torchaudio-2.3.0     | 5.7 MB    | #######3   |  74%
# torchaudio-2.3.0     | 5.7 MB    | #######6   |  76%
# torchaudio-2.3.0     | 5.7 MB    | #######8   |  78%
# torchaudio-2.3.0     | 5.7 MB    | ########   |  80%
# torchaudio-2.3.0     | 5.7 MB    | ########2  |  83%
# torchaudio-2.3.0     | 5.7 MB    | ########5  |  85%
# torchaudio-2.3.0     | 5.7 MB    | ########7  |  87%
# torchaudio-2.3.0     | 5.7 MB    | ########9  |  90%
# torchaudio-2.3.0     | 5.7 MB    | #########1 |  92%
# torchaudio-2.3.0     | 5.7 MB    | #########4 |  94%
# torchaudio-2.3.0     | 5.7 MB    | #########6 |  96%
# torchaudio-2.3.0     | 5.7 MB    | #########8 |  98%
# torchaudio-2.3.0     | 5.7 MB    | ########## | 100%
#
# libjpeg-turbo-2.0.0  | 618 KB    |            |   0%
# libjpeg-turbo-2.0.0  | 618 KB    | 2          |   3%
# libjpeg-turbo-2.0.0  | 618 KB    | ##         |  21%
# libjpeg-turbo-2.0.0  | 618 KB    | ###8       |  39%
# libjpeg-turbo-2.0.0  | 618 KB    | ######2    |  62%
# libjpeg-turbo-2.0.0  | 618 KB    | ########5  |  85%
# libjpeg-turbo-2.0.0  | 618 KB    | ########## | 100%
#
# pytorch-mutex-1.0    | 3 KB      |            |   0%
# pytorch-mutex-1.0    | 3 KB      | ########## | 100%
#
# libuv-1.44.2         | 288 KB    |            |   0%
# libuv-1.44.2         | 288 KB    | #6         |  17%
# libuv-1.44.2         | 288 KB    | ######1    |  61%
# libuv-1.44.2         | 288 KB    | ########## | 100%
# libuv-1.44.2         | 288 KB    | ########## | 100%
#
# torchvision-0.18.0   | 6.5 MB    |            |   0%
# torchvision-0.18.0   | 6.5 MB    |            |   0%
# torchvision-0.18.0   | 6.5 MB    | 2          |   2%
# torchvision-0.18.0   | 6.5 MB    | 4          |   4%
# torchvision-0.18.0   | 6.5 MB    | 6          |   6%
# torchvision-0.18.0   | 6.5 MB    | 8          |   8%
# torchvision-0.18.0   | 6.5 MB    | #          |  10%
# torchvision-0.18.0   | 6.5 MB    | #2         |  12%
# torchvision-0.18.0   | 6.5 MB    | #4         |  14%
# torchvision-0.18.0   | 6.5 MB    | #5         |  16%
# torchvision-0.18.0   | 6.5 MB    | #7         |  18%
# torchvision-0.18.0   | 6.5 MB    | #9         |  20%
# torchvision-0.18.0   | 6.5 MB    | ##1        |  22%
# torchvision-0.18.0   | 6.5 MB    | ##3        |  24%
# torchvision-0.18.0   | 6.5 MB    | ##5        |  26%
# torchvision-0.18.0   | 6.5 MB    | ##7        |  28%
# torchvision-0.18.0   | 6.5 MB    | ##9        |  30%
# torchvision-0.18.0   | 6.5 MB    | ###1       |  32%
# torchvision-0.18.0   | 6.5 MB    | ###3       |  34%
# torchvision-0.18.0   | 6.5 MB    | ###5       |  36%
# torchvision-0.18.0   | 6.5 MB    | ###7       |  37%
# torchvision-0.18.0   | 6.5 MB    | ###9       |  39%
# torchvision-0.18.0   | 6.5 MB    | ####1      |  41%
# torchvision-0.18.0   | 6.5 MB    | ####3      |  43%
# torchvision-0.18.0   | 6.5 MB    | ####5      |  45%
# torchvision-0.18.0   | 6.5 MB    | ####7      |  47%
# torchvision-0.18.0   | 6.5 MB    | ####9      |  49%
# torchvision-0.18.0   | 6.5 MB    | #####1     |  51%
# torchvision-0.18.0   | 6.5 MB    | #####3     |  53%
# torchvision-0.18.0   | 6.5 MB    | #####5     |  55%
# torchvision-0.18.0   | 6.5 MB    | #####7     |  57%
# torchvision-0.18.0   | 6.5 MB    | #####9     |  59%
# torchvision-0.18.0   | 6.5 MB    | ######1    |  62%
# torchvision-0.18.0   | 6.5 MB    | ######3    |  64%
# torchvision-0.18.0   | 6.5 MB    | ######5    |  66%
# torchvision-0.18.0   | 6.5 MB    | ######7    |  68%
# torchvision-0.18.0   | 6.5 MB    | ######9    |  70%
# torchvision-0.18.0   | 6.5 MB    | #######1   |  72%
# torchvision-0.18.0   | 6.5 MB    | #######3   |  73%
# torchvision-0.18.0   | 6.5 MB    | #######5   |  75%
# torchvision-0.18.0   | 6.5 MB    | #######7   |  77%
# torchvision-0.18.0   | 6.5 MB    | #######9   |  79%
# torchvision-0.18.0   | 6.5 MB    | ########1  |  81%
# torchvision-0.18.0   | 6.5 MB    | ########3  |  83%
# torchvision-0.18.0   | 6.5 MB    | ########5  |  85%
# torchvision-0.18.0   | 6.5 MB    | ########7  |  87%
# torchvision-0.18.0   | 6.5 MB    | ########9  |  89%
# torchvision-0.18.0   | 6.5 MB    | #########1 |  91%
# torchvision-0.18.0   | 6.5 MB    | #########3 |  94%
# torchvision-0.18.0   | 6.5 MB    | #########5 |  95%
# torchvision-0.18.0   | 6.5 MB    | #########7 |  97%
# torchvision-0.18.0   | 6.5 MB    | #########9 |  99%
# torchvision-0.18.0   | 6.5 MB    | ########## | 100%
#
# cpuonly-2.0          | 2 KB      |            |   0%
# cpuonly-2.0          | 2 KB      | ########## | 100%
#
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   1%
# pytorch-2.3.0        | 138.3 MB  |            |   1%
# pytorch-2.3.0        | 138.3 MB  |            |   1%
# pytorch-2.3.0        | 138.3 MB  |            |   1%
# pytorch-2.3.0        | 138.3 MB  |            |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   1%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 2          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   3%
# pytorch-2.3.0        | 138.3 MB  | 3          |   4%
# pytorch-2.3.0        | 138.3 MB  | 3          |   4%
# pytorch-2.3.0        | 138.3 MB  | 3          |   4%
# pytorch-2.3.0        | 138.3 MB  | 3          |   4%
# pytorch-2.3.0        | 138.3 MB  | 3          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 4          |   5%
# pytorch-2.3.0        | 138.3 MB  | 4          |   5%
# pytorch-2.3.0        | 138.3 MB  | 4          |   5%
# pytorch-2.3.0        | 138.3 MB  | 4          |   5%
# pytorch-2.3.0        | 138.3 MB  | 4          |   5%
# pytorch-2.3.0        | 138.3 MB  | 5          |   5%
# pytorch-2.3.0        | 138.3 MB  | 5          |   5%
# pytorch-2.3.0        | 138.3 MB  | 5          |   5%
# pytorch-2.3.0        | 138.3 MB  | 5          |   5%
# pytorch-2.3.0        | 138.3 MB  | 5          |   5%
# pytorch-2.3.0        | 138.3 MB  | 5          |   6%
# pytorch-2.3.0        | 138.3 MB  | 5          |   6%
# pytorch-2.3.0        | 138.3 MB  | 5          |   6%
# pytorch-2.3.0        | 138.3 MB  | 5          |   6%
# pytorch-2.3.0        | 138.3 MB  | 5          |   6%
# pytorch-2.3.0        | 138.3 MB  | 5          |   6%
# pytorch-2.3.0        | 138.3 MB  | 6          |   6%
# pytorch-2.3.0        | 138.3 MB  | 6          |   6%
# pytorch-2.3.0        | 138.3 MB  | 6          |   6%
# pytorch-2.3.0        | 138.3 MB  | 6          |   6%
# pytorch-2.3.0        | 138.3 MB  | 6          |   6%
# pytorch-2.3.0        | 138.3 MB  | 6          |   7%
# pytorch-2.3.0        | 138.3 MB  | 6          |   7%
# pytorch-2.3.0        | 138.3 MB  | 6          |   7%
# pytorch-2.3.0        | 138.3 MB  | 6          |   7%
# pytorch-2.3.0        | 138.3 MB  | 6          |   7%
# pytorch-2.3.0        | 138.3 MB  | 7          |   7%
# pytorch-2.3.0        | 138.3 MB  | 7          |   7%
# pytorch-2.3.0        | 138.3 MB  | 7          |   7%
# pytorch-2.3.0        | 138.3 MB  | 7          |   7%
# pytorch-2.3.0        | 138.3 MB  | 7          |   7%
# pytorch-2.3.0        | 138.3 MB  | 7          |   8%
# pytorch-2.3.0        | 138.3 MB  | 7          |   8%
# pytorch-2.3.0        | 138.3 MB  | 7          |   8%
# pytorch-2.3.0        | 138.3 MB  | 7          |   8%
# pytorch-2.3.0        | 138.3 MB  | 7          |   8%
# pytorch-2.3.0        | 138.3 MB  | 7          |   8%
# pytorch-2.3.0        | 138.3 MB  | 8          |   8%
# pytorch-2.3.0        | 138.3 MB  | 8          |   8%
# pytorch-2.3.0        | 138.3 MB  | 8          |   8%
# pytorch-2.3.0        | 138.3 MB  | 8          |   8%
# pytorch-2.3.0        | 138.3 MB  | 8          |   8%
# pytorch-2.3.0        | 138.3 MB  | 8          |   9%
# pytorch-2.3.0        | 138.3 MB  | 8          |   9%
# pytorch-2.3.0        | 138.3 MB  | 8          |   9%
# pytorch-2.3.0        | 138.3 MB  | 8          |   9%
# pytorch-2.3.0        | 138.3 MB  | 8          |   9%
# pytorch-2.3.0        | 138.3 MB  | 8          |   9%
# pytorch-2.3.0        | 138.3 MB  | 9          |   9%
# pytorch-2.3.0        | 138.3 MB  | 9          |   9%
# pytorch-2.3.0        | 138.3 MB  | 9          |   9%
# pytorch-2.3.0        | 138.3 MB  | 9          |   9%
# pytorch-2.3.0        | 138.3 MB  | 9          |   9%
# pytorch-2.3.0        | 138.3 MB  | 9          |  10%
# pytorch-2.3.0        | 138.3 MB  | 9          |  10%
# pytorch-2.3.0        | 138.3 MB  | 9          |  10%
# pytorch-2.3.0        | 138.3 MB  | 9          |  10%
# pytorch-2.3.0        | 138.3 MB  | 9          |  10%
# pytorch-2.3.0        | 138.3 MB  | 9          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #          |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  11%
# pytorch-2.3.0        | 138.3 MB  | #1         |  12%
# pytorch-2.3.0        | 138.3 MB  | #1         |  12%
# pytorch-2.3.0        | 138.3 MB  | #1         |  12%
# pytorch-2.3.0        | 138.3 MB  | #1         |  12%
# pytorch-2.3.0        | 138.3 MB  | #1         |  12%
# pytorch-2.3.0        | 138.3 MB  | #2         |  12%
# pytorch-2.3.0        | 138.3 MB  | #2         |  12%
# pytorch-2.3.0        | 138.3 MB  | #2         |  12%
# pytorch-2.3.0        | 138.3 MB  | #2         |  12%
# pytorch-2.3.0        | 138.3 MB  | #2         |  12%
# pytorch-2.3.0        | 138.3 MB  | #2         |  13%
# pytorch-2.3.0        | 138.3 MB  | #2         |  13%
# pytorch-2.3.0        | 138.3 MB  | #2         |  13%
# pytorch-2.3.0        | 138.3 MB  | #2         |  13%
# pytorch-2.3.0        | 138.3 MB  | #2         |  13%
# pytorch-2.3.0        | 138.3 MB  | #2         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  13%
# pytorch-2.3.0        | 138.3 MB  | #3         |  14%
# pytorch-2.3.0        | 138.3 MB  | #3         |  14%
# pytorch-2.3.0        | 138.3 MB  | #3         |  14%
# pytorch-2.3.0        | 138.3 MB  | #3         |  14%
# pytorch-2.3.0        | 138.3 MB  | #3         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  14%
# pytorch-2.3.0        | 138.3 MB  | #4         |  15%
# pytorch-2.3.0        | 138.3 MB  | #4         |  15%
# pytorch-2.3.0        | 138.3 MB  | #4         |  15%
# pytorch-2.3.0        | 138.3 MB  | #4         |  15%
# pytorch-2.3.0        | 138.3 MB  | #4         |  15%
# pytorch-2.3.0        | 138.3 MB  | #5         |  15%
# pytorch-2.3.0        | 138.3 MB  | #5         |  15%
# pytorch-2.3.0        | 138.3 MB  | #5         |  15%
# pytorch-2.3.0        | 138.3 MB  | #5         |  15%
# pytorch-2.3.0        | 138.3 MB  | #5         |  15%
# pytorch-2.3.0        | 138.3 MB  | #5         |  16%
# pytorch-2.3.0        | 138.3 MB  | #5         |  16%
# pytorch-2.3.0        | 138.3 MB  | #5         |  16%
# pytorch-2.3.0        | 138.3 MB  | #5         |  16%
# pytorch-2.3.0        | 138.3 MB  | #5         |  16%
# pytorch-2.3.0        | 138.3 MB  | #5         |  16%
# pytorch-2.3.0        | 138.3 MB  | #6         |  16%
# pytorch-2.3.0        | 138.3 MB  | #6         |  16%
# pytorch-2.3.0        | 138.3 MB  | #6         |  16%
# pytorch-2.3.0        | 138.3 MB  | #6         |  16%
# pytorch-2.3.0        | 138.3 MB  | #6         |  16%
# pytorch-2.3.0        | 138.3 MB  | #6         |  17%
# pytorch-2.3.0        | 138.3 MB  | #6         |  17%
# pytorch-2.3.0        | 138.3 MB  | #6         |  17%
# pytorch-2.3.0        | 138.3 MB  | #6         |  17%
# pytorch-2.3.0        | 138.3 MB  | #6         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #7         |  18%
# pytorch-2.3.0        | 138.3 MB  | #7         |  18%
# pytorch-2.3.0        | 138.3 MB  | #7         |  18%
# pytorch-2.3.0        | 138.3 MB  | #7         |  18%
# pytorch-2.3.0        | 138.3 MB  | #7         |  18%
# pytorch-2.3.0        | 138.3 MB  | #7         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  18%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #8         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  19%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##         |  21%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  21%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  21%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  21%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  21%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  21%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##2        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  23%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##3        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  25%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##5        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  26%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##7        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  28%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  29%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  30%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  30%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  30%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  30%
# pytorch-2.3.0        | 138.3 MB  | ##9        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  30%
# pytorch-2.3.0        | 138.3 MB  | ###        |  31%
# pytorch-2.3.0        | 138.3 MB  | ###        |  31%
# pytorch-2.3.0        | 138.3 MB  | ###        |  31%
# pytorch-2.3.0        | 138.3 MB  | ###        |  31%
# pytorch-2.3.0        | 138.3 MB  | ###        |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  32%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###2       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  34%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###5       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  38%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####       |  41%
# pytorch-2.3.0        | 138.3 MB  | ####       |  41%
# pytorch-2.3.0        | 138.3 MB  | ####       |  41%
# pytorch-2.3.0        | 138.3 MB  | ####       |  41%
# pytorch-2.3.0        | 138.3 MB  | ####       |  41%
# pytorch-2.3.0        | 138.3 MB  | ####       |  41%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  41%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  41%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  41%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  41%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  41%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####2      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  44%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####4      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  46%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####6      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  48%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####8      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  49%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  50%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  50%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  50%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  50%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####      |  51%
# pytorch-2.3.0        | 138.3 MB  | #####      |  51%
# pytorch-2.3.0        | 138.3 MB  | #####      |  51%
# pytorch-2.3.0        | 138.3 MB  | #####      |  51%
# pytorch-2.3.0        | 138.3 MB  | #####      |  51%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  51%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  51%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  51%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  51%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  51%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####2     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  54%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####4     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  55%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####6     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  57%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  58%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####8     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  59%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  60%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  60%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  60%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  60%
# pytorch-2.3.0        | 138.3 MB  | #####9     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######     |  61%
# pytorch-2.3.0        | 138.3 MB  | ######     |  61%
# pytorch-2.3.0        | 138.3 MB  | ######     |  61%
# pytorch-2.3.0        | 138.3 MB  | ######     |  61%
# pytorch-2.3.0        | 138.3 MB  | ######     |  61%
# pytorch-2.3.0        | 138.3 MB  | ######1    |  61%
# pytorch-2.3.0        | 138.3 MB  | ######1    |  61%
# pytorch-2.3.0        | 138.3 MB  | ######1    |  61%
# pytorch-2.3.0        | 138.3 MB  | ######1    |  61%
# pytorch-2.3.0        | 138.3 MB  | ######1    |  61%
# ...
# pytorch-2.3.0        | 138.3 MB  | #######3   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######3   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######3   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######3   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  74%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######4   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  75%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######5   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  80%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  80%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  80%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  80%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  81%
# pytorch-2.3.0        | 138.3 MB  | ########   |  81%
# pytorch-2.3.0        | 138.3 MB  | ########   |  81%
# pytorch-2.3.0        | 138.3 MB  | ########   |  81%
# pytorch-2.3.0        | 138.3 MB  | ########   |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  89%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  90%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  90%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  90%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  90%
# pytorch-2.3.0        | 138.3 MB  | ########9  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########  |  91%
# pytorch-2.3.0        | 138.3 MB  | #########  |  91%
# pytorch-2.3.0        | 138.3 MB  | #########  |  91%
# pytorch-2.3.0        | 138.3 MB  | #########  |  91%
# pytorch-2.3.0        | 138.3 MB  | #########  |  91%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  91%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  91%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  91%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  91%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  91%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  93%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########3 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  97%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########7 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  98%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 |  99%
# pytorch-2.3.0        | 138.3 MB  | #########9 | 100%
# pytorch-2.3.0        | 138.3 MB  | #########9 | 100%
# pytorch-2.3.0        | 138.3 MB  | #########9 | 100%
# pytorch-2.3.0        | 138.3 MB  | #########9 | 100%
# pytorch-2.3.0        | 138.3 MB  | #########9 | 100%
# pytorch-2.3.0        | 138.3 MB  | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Generate the additional 200 samples for each hypothesis
X_train, y_train = generate_data(200)

# Convert to torch tensors
X_train_tensor = torch.from_numpy(X_train).float()
y_train_tensor = torch.from_numpy(y_train).float().view(-1, 1)

# Create a DataLoader for training data
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=20, shuffle=True)

# %%
# Define the neural network model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(2, 20)
        self.fc2 = nn.Linear(20, 20)
        self.fc3 = nn.Linear(20, 1)
    
    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x

# %%
# Instantiate two networks, one for cross-entropy and one for exponential loss
net_ce = Net()
net_exp = Net()

# Define the loss functions
criterion_ce = nn.BCELoss()  # Binary cross-entropy
def exponential_loss(output, target):
    return torch.mean(0.5 * torch.exp(0.5 * (output - target)**2))

# Define the optimizers
optimizer_ce = optim.SGD(net_ce.parameters(), lr=0.01)
optimizer_exp = optim.SGD(net_exp.parameters(), lr=0.01)

# %%
# Training function
def train_network(net, criterion, optimizer, epochs=1000):
    for epoch in range(epochs):
        for data in train_loader:
            inputs, labels = data
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

# %%
# Train both networks
train_network(net_ce, criterion_ce, optimizer_ce)
train_network(net_exp, exponential_loss, optimizer_exp)

# %%
#Generate a large test dataset to evaluate performance
X_test, y_test = generate_data(10**6)
X_test_tensor = torch.from_numpy(X_test).float()
y_test_tensor = torch.from_numpy(y_test).float().view(-1, 1)

# %%
# Evaluate the networks on the test data
with torch.no_grad():
    outputs_ce = net_ce(X_test_tensor)
    outputs_exp = net_exp(X_test_tensor)

# Apply the decision rule: classify as H1 if output > 0.5
y_pred_ce = (outputs_ce > 0.5).float()
y_pred_exp = (outputs_exp > 0.5).float()

# %%
# Compute error rates
error_rate_ce = torch.mean((y_pred_ce != y_test_tensor).float())
error_rate_exp = torch.mean((y_pred_exp != y_test_tensor).float())

print(f'Cross-Entropy NN Error Rate: {error_rate_ce.item()}')
print(f'Exponential Loss NN Error Rate: {error_rate_exp.item()}')
# Out:
# Cross-Entropy NN Error Rate: 0.39997598528862
# Exponential Loss NN Error Rate: 0.5012425184249878

# %%
# Compare with Bayes Decision Rule
def bayes_decision_rule(x):
    f0 = np.exp(-0.5 * np.sum(x**2, axis=1))
    f1 = 0.5 * (np.exp(-0.5 * (x[:, 0] - 1)**2) + np.exp(-0.5 * (x[:, 0] + 1)**2)) * np.exp(-0.5 * x[:, 1]**2)
    return f1 > f0

y_bayes = bayes_decision_rule(X_test)
error_rate_bayes = np.mean(y_bayes != y_test)
print(f'Bayes Decision Rule Error Rate: {error_rate_bayes}')
# Out:
# Bayes Decision Rule Error Rate: 0.396736
